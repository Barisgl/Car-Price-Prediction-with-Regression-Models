# %% [markdown]
# ## WELCOME

# %%
import pandas as pd      
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

from scipy.stats import skew

from sklearn.model_selection import cross_validate, cross_val_score
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('display.max_columns', 500) 
pd.set_option('display.max_rows', 500)
from sklearn.linear_model import LinearRegression
pd.options.display.float_format = '{:.3f}'.format
from yellowbrick.regressor import PredictionError
from yellowbrick.features import RadViz
from yellowbrick.regressor import ResidualsPlot
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score as acc
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("final_scout_not_dummy.csv")

# %%
df.head()
# Out:
#   make_model body_type  price        km  Type     Fuel  \
# 0    Audi A1    Sedans  15770 56013.000  Used   Diesel
# 1    Audi A1    Sedans  14500 80000.000  Used  Benzine
# 2    Audi A1    Sedans  14640 83450.000  Used   Diesel
# 3    Audi A1    Sedans  14500 73000.000  Used   Diesel
# 4    Audi A1    Sedans  16790 16200.000  Used   Diesel
#
#                                  Comfort_Convenience  \
# 0  Air conditioning,Armrest,Automatic climate con...
# 1  Air conditioning,Automatic climate control,Hil...
# 2  Air conditioning,Cruise control,Electrical sid...
# 3  Air suspension,Armrest,Auxiliary heating,Elect...
# 4  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               Extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                      Safety_Security  Gears   age  \
# 0  ABS,Central door lock,Daytime running lights,D...  7.000 3.000
# 1  ABS,Central door lock,Central door lock with r...  7.000 2.000
# 2  ABS,Central door lock,Daytime running lights,D...  7.000 3.000
# 3  ABS,Alarm system,Central door lock with remote...  6.000 3.000
# 4  ABS,Central door lock,Driver-side airbag,Elect...  7.000 3.000
#
#    Previous_Owners   hp_kW  Inspection_new Paint_Type Upholstery_type  \
# 0            2.000  66.000               1   Metallic           Cloth
# 1            1.000 141.000               0   Metallic           Cloth
# 2            1.000  85.000               0   Metallic           Cloth
# 3            1.000  66.000               0   Metallic           Cloth
# 4            1.000  66.000               1   Metallic           Cloth
#
#   Gearing_Type  Displacement_cc  Weight_kg Drive_chain  CO2_Emission
# 0    Automatic         1422.000   1220.000       front        99.000
# 1    Automatic         1798.000   1255.000       front       129.000
# 2    Automatic         1598.000   1135.000       front        99.000
# 3    Automatic         1422.000   1195.000       front        99.000
# 4    Automatic         1422.000   1135.000       front       109.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15909 entries, 0 to 15908
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15909 non-null  object
#  1   body_type            15909 non-null  object
#  2   price                15909 non-null  int64
#  3   km                   15909 non-null  float64
#  4   Type                 15909 non-null  object
#  5   Fuel                 15909 non-null  object
#  6   Comfort_Convenience  15909 non-null  object
#  7   Entertainment_Media  15909 non-null  object
#  8   Extras               15909 non-null  object
#  9   Safety_Security      15909 non-null  object
#  10  Gears                15909 non-null  float64
#  11  age                  15909 non-null  float64
#  12  Previous_Owners      15909 non-null  float64
#  13  hp_kW                15909 non-null  float64
#  14  Inspection_new       15909 non-null  int64
#  15  Paint_Type           15909 non-null  object
#  16  Upholstery_type      15909 non-null  object
#  17  Gearing_Type         15909 non-null  object
#  18  Displacement_cc      15909 non-null  float64
#  19  Weight_kg            15909 non-null  float64
#  20  Drive_chain          15909 non-null  object
#  21  CO2_Emission         15909 non-null  float64
# dtypes: float64(8), int64(2), object(12)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#           price         km     Gears       age  Previous_Owners     hp_kW  \
# count 15909.000  15909.000 15909.000 15909.000        15909.000 15909.000
# mean  18020.242  32092.437     5.937     1.390            1.043    88.498
# std    7377.201  36982.839     0.705     1.121            0.339    26.667
# min    4950.000      0.000     5.000     0.000            0.000    51.000
# 25%   12850.000   1913.000     5.000     0.000            1.000    66.000
# 50%   16900.000  20410.000     6.000     1.000            1.000    85.000
# 75%   21900.000  46900.000     6.000     2.000            1.000   103.000
# max   74600.000 317000.000     8.000     3.000            4.000   294.000
#
#        Inspection_new  Displacement_cc  Weight_kg  CO2_Emission
# count       15909.000        15909.000  15909.000     15909.000
# mean            0.247         1428.657   1337.675       117.783
# std             0.431          275.852    199.672        18.023
# min             0.000          890.000    840.000        45.000
# 25%             0.000         1229.000   1165.000       104.000
# 50%             0.000         1461.000   1295.000       117.000
# 75%             0.000         1598.000   1472.000       129.000
# max             1.000         2967.000   2471.000       253.000

# %% [markdown]
# ## Feature Engineering

# %%
for col in df.select_dtypes('object'):
    print(f"{col:<20}:", df[col].nunique())
# Out:
# make_model          : 8
# body_type           : 8
# Type                : 5
# Fuel                : 3
# Comfort_Convenience : 6193
# Entertainment_Media : 346
# Extras              : 659
# Safety_Security     : 4439
# Paint_Type          : 3
# Upholstery_type     : 2
# Gearing_Type        : 3
# Drive_chain         : 3

# %%
df.make_model.value_counts()
# Out:
# Audi A3           3093
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2525
# Opel Corsa        2216
# Renault Clio      1838
# Renault Espace     991
# Renault Duster      34
# Name: make_model, dtype: int64

# %%
ax = df.make_model.value_counts().plot(kind ="bar")
ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False)
#ax.axis("off")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.03, p.get_height() * 1.03))

# %%
sns.histplot(df.price, bins=50, kde=True);

# %%
sns.boxplot(df.price)

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x="make_model", y="price", data=df, whis=3)
plt.show()

# %% [markdown]
# ## Get dummies

# %%
df = df.join(df["Comfort_Convenience"].str.get_dummies(sep = ",").add_prefix("cc_")) 
df = df.join(df["Entertainment_Media"].str.get_dummies(sep = ",").add_prefix("em_"))
df = df.join(df["Extras"].str.get_dummies(sep = ",").add_prefix("ex_"))
df = df.join(df["Safety_Security"].str.get_dummies(sep = ",").add_prefix("ss_"))
df.drop(["Comfort_Convenience","Entertainment_Media","Extras","Safety_Security"], axis=1, inplace=True)
df = pd.get_dummies(df, drop_first =True)

# %% [markdown]
# ## Data Pre-Processing

# %%
X= df.drop(columns="price")
y= df.price
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# ## 1) Implement Linear Regression

# %%
def train_val(model, X_train, y_train, X_test, y_test):
    
    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train) # overfitting var mı yok mu kıyaslamak için
    
    scores = {"train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    "test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
train_val(lm, X_train, y_train, X_test, y_test)
# Out:
#            train        test
# R2         0.890       0.890
# mae     1704.693    1695.114
# mse  6003486.622 5834182.497
# rmse    2450.201    2415.405

# %% [markdown]
# ### Cross-Validation

# %%
model = LinearRegression()
scores = cross_validate(model, X_train, y_train, scoring=['r2', 
            'neg_mean_absolute_error','neg_mean_squared_error','neg_root_mean_squared_error'], cv =10)

# %%
pd.DataFrame(scores).iloc[:, 2:].mean()
# Out:
# test_r2                                   0.887
# test_neg_mean_absolute_error          -1727.081
# test_neg_mean_squared_error        -6197195.607
# test_neg_root_mean_squared_error      -2486.897
# dtype: float64

# %%
train_val(lm, X_train, y_train, X_test, y_test)
# Out:
#            train        test
# R2         0.890       0.890
# mae     1704.693    1695.114
# mse  6003486.622 5834182.497
# rmse    2450.201    2415.405

# %% [markdown]
# ### Dropping observations from the dataset that worsen my predictions

# %%
df3 = df[~(df.price>35000)]

# %%
X = df3.drop(columns = "price")
y = df3.price

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
lm2 = LinearRegression()
lm2.fit(X_train,y_train)
train_val(lm2, X_train, y_train, X_test, y_test)
# Out:
#            train        test
# R2         0.901       0.898
# mae     1409.321    1419.488
# mse  3744927.420 3815062.117
# rmse    1935.181    1953.218

# %%
y_pred = lm2.predict(X_test)

lm_R2 = r2_score(y_test, y_pred)
lm_mae = mean_absolute_error(y_test, y_pred)
lm_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# ## 2. Implement Ridge Regression

# %% [markdown]
# ### Scaling

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Ridge

# %%
ridge_model = Ridge(random_state=42)
ridge_model.fit(X_train_scaled, y_train)
train_val(ridge_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#            train        test
# R2         0.900       0.898
# mae     1409.137    1419.395
# mse  3746196.292 3813993.830
# rmse    1935.509    1952.945

# %% [markdown]
# ### Finding best alpha

# %%
alpha_space = np.linspace(0.01, 100, 100)
ridge_model = Ridge(random_state=42)

param_grid = {'alpha':alpha_space}

ridge_grid_model = GridSearchCV(estimator=ridge_model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)
ridge_grid_model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(random_state=42), n_jobs=-1,
#              param_grid={'alpha': array([1.000e-02, 1.020e+00, 2.030e+00, 3.040e+00, 4.050e+00, 5.060e+00,
#        6.070e+00, 7.080e+00, 8.090e+00, 9.100e+00, 1.011e+01, 1.112e+01,
#        1.213e+01, 1.314e+01, 1.415e+01, 1.516e+01, 1.617e+01, 1.718e+01,
#        1.819e+01, 1.920e+01, 2.021e+01, 2.122e+01, 2.223e+01, 2.324e+01,
#        2.425e+01, 2.526e+01, 2...
#        6.667e+01, 6.768e+01, 6.869e+01, 6.970e+01, 7.071e+01, 7.172e+01,
#        7.273e+01, 7.374e+01, 7.475e+01, 7.576e+01, 7.677e+01, 7.778e+01,
#        7.879e+01, 7.980e+01, 8.081e+01, 8.182e+01, 8.283e+01, 8.384e+01,
#        8.485e+01, 8.586e+01, 8.687e+01, 8.788e+01, 8.889e+01, 8.990e+01,
#        9.091e+01, 9.192e+01, 9.293e+01, 9.394e+01, 9.495e+01, 9.596e+01,
#        9.697e+01, 9.798e+01, 9.899e+01, 1.000e+02])},
#              scoring='neg_root_mean_squared_error')

# %%
ridge_grid_model.best_estimator_
# Out:
# Ridge(alpha=1.02, random_state=42)

# %%
y_pred = ridge_grid_model.predict(X_test_scaled)
rm_R2 = r2_score(y_test, y_pred)
rm_mae = mean_absolute_error(y_test, y_pred)
rm_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
ridge = Ridge(alpha=1.02, random_state=42).fit(X_train_scaled, y_train)

# %% [markdown]
# ## 3. Implement Lasso Regression

# %%
lasso_model = Lasso(random_state=42)
lasso_model.fit(X_train_scaled, y_train)
# Out:
# Lasso(random_state=42)

# %%
train_val(lasso_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#            train        test
# R2         0.900       0.898
# mae     1410.356    1418.036
# mse  3757208.876 3809506.757
# rmse    1938.352    1951.796

# %% [markdown]
# ### Finding best alpha for Lasso

# %%
lasso_model = Lasso(random_state=42)

param_grid = {'alpha':alpha_space}

lasso_grid_model = GridSearchCV(estimator=lasso_model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)
lasso_grid_model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=10, estimator=Lasso(random_state=42), n_jobs=-1,
#              param_grid={'alpha': array([1.000e-02, 1.020e+00, 2.030e+00, 3.040e+00, 4.050e+00, 5.060e+00,
#        6.070e+00, 7.080e+00, 8.090e+00, 9.100e+00, 1.011e+01, 1.112e+01,
#        1.213e+01, 1.314e+01, 1.415e+01, 1.516e+01, 1.617e+01, 1.718e+01,
#        1.819e+01, 1.920e+01, 2.021e+01, 2.122e+01, 2.223e+01, 2.324e+01,
#        2.425e+01, 2.526e+01, 2...
#        6.667e+01, 6.768e+01, 6.869e+01, 6.970e+01, 7.071e+01, 7.172e+01,
#        7.273e+01, 7.374e+01, 7.475e+01, 7.576e+01, 7.677e+01, 7.778e+01,
#        7.879e+01, 7.980e+01, 8.081e+01, 8.182e+01, 8.283e+01, 8.384e+01,
#        8.485e+01, 8.586e+01, 8.687e+01, 8.788e+01, 8.889e+01, 8.990e+01,
#        9.091e+01, 9.192e+01, 9.293e+01, 9.394e+01, 9.495e+01, 9.596e+01,
#        9.697e+01, 9.798e+01, 9.899e+01, 1.000e+02])},
#              scoring='neg_root_mean_squared_error')

# %%
train_val(lasso_grid_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#            train        test
# R2         0.900       0.898
# mae     1410.394    1418.047
# mse  3757620.533 3809665.746
# rmse    1938.458    1951.837

# %%
y_pred = lasso_grid_model.predict(X_test_scaled)
lasm_R2 = r2_score(y_test, y_pred)
lasm_mae = mean_absolute_error(y_test, y_pred)
lasm_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# ## 4. Implement Elastic-Net

# %%
elastic_model = ElasticNet(random_state=42)
elastic_model.fit(X_train_scaled,y_train)
train_val(elastic_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#             train         test
# R2          0.597        0.604
# mae      3081.429     3028.555
# mse  15153451.715 14790992.779
# rmse     3892.743     3845.906

# %% [markdown]
# ### Finding best alpha and l1_ratio for ElasticNet

# %%
elastic_model = ElasticNet(random_state=42)
param_grid = {'alpha':[1.02, 2,  3, 4, 5, 7, 10, 11],
              'l1_ratio':[.5, .7, .9, .95, .99, 1]}

elastic_grid_model = GridSearchCV(estimator=elastic_model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)
elastic_grid_model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=10, estimator=ElasticNet(random_state=42), n_jobs=-1,
#              param_grid={'alpha': [1.02, 2, 3, 4, 5, 7, 10, 11],
#                          'l1_ratio': [0.5, 0.7, 0.9, 0.95, 0.99, 1]},
#              scoring='neg_root_mean_squared_error')

# %%
train_val(elastic_grid_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
#            train        test
# R2         0.900       0.898
# mae     1410.394    1418.047
# mse  3757620.533 3809665.746
# rmse    1938.458    1951.837

# %%
y_pred = elastic_grid_model.predict(X_test_scaled)
em_R2 = r2_score(y_test, y_pred)
em_mae = mean_absolute_error(y_test, y_pred)
em_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# ## 5. Implement Decision Tree

# %%
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_train, y_train)
train_val(regressor, X_train, y_train, X_test, y_test)
# Out:
#          train        test
# R2       1.000       0.921
# mae     19.498    1011.847
# mse  17031.335 2945531.347
# rmse   130.504    1716.255

# %% [markdown]
# ### Finding best hyperparmeters

# %%
parameters={"splitter":["best","random"],
            "max_depth" : [None,1,3,5],
           "min_samples_leaf":[1,2,3,4,5,6,7],
           "min_samples_split" : [2,3,5,6,7,8,9] }

# %%
tuning_model=GridSearchCV(regressor,param_grid=parameters,scoring='neg_mean_squared_error',cv=5,verbose=3)

# %%
tuning_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of
total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-2963832.770 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-3049480.227 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-2737087.912 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-2696466.535 total time=   0.2s
# [CV 2/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-2942824.507 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-2541719.811 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-3054901.447 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-2651410.516 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-2550995.628 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-3277775.359 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-2963832.770 total time=   0.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-3049480.227 total time=   0.1s
# [CV 5/5] END max_depth=None, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-2737087.912 total time=   0.1s
# [CV 1/5] END max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-2696466.535 total time=   0.1s
# [CV 2/5] END max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-2942824.507 total time=   0.1s
# [CV 3/5] END max_depth=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-2541719.811 total time=   0.2s
# ...
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=3, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-7578849.420 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=5, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=7, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=6, min_samples_split=9, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=2, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=3, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=5, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=6, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=7, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=8, splitter=random;, score=-9618489.773 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=best;, score=-6733057.887 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=best;, score=-7055567.416 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=best;, score=-6572857.303 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=best;, score=-6532717.760 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=best;, score=-6683346.858 total time=   0.1s
# [CV 1/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=random;, score=-7578849.420 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=random;, score=-8770961.802 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=random;, score=-9234809.164 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=random;, score=-7342612.132 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=7, min_samples_split=9, splitter=random;, score=-9618489.773 total time=   0.1s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#              param_grid={'max_depth': [None, 1, 3, 5],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7],
#                          'min_samples_split': [2, 3, 5, 6, 7, 8, 9],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
tuning_model.best_params_
# Out:
# {'max_depth': None,
#  'min_samples_leaf': 7,
#  'min_samples_split': 2,
#  'splitter': 'best'}

# %%
tuned_hyper_model= DecisionTreeRegressor(max_depth=None,min_samples_leaf=7,min_samples_split=2,splitter='best')

# %%
tuned_hyper_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(min_samples_leaf=7)

# %%
train_val(tuned_hyper_model, X_train, y_train, X_test, y_test)
# Out:
#            train        test
# R2         0.969       0.937
# mae      686.418     992.501
# mse  1170761.404 2355194.114
# rmse    1082.017    1534.664

# %%
y_pred = tuned_hyper_model.predict(X_test)
des_R2 = r2_score(y_test, y_pred)
des_mae = mean_absolute_error(y_test, y_pred)
des_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# ## 7. Implement Random Forest

# %%
regres = RandomForestRegressor(n_estimators = 10, random_state = 0)
regres.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
train_val(regres, X_train, y_train, X_test, y_test)
# Out:
#           train        test
# R2        0.991       0.957
# mae     342.925     812.060
# mse  342665.826 1611482.077
# rmse    585.377    1269.442

# %% [markdown]
# ### Finding best hyperparmeters

# %%
parameters1={"n_estimators":[200,500],
            "max_depth" : [None,4,5,6,7],
           "min_samples_leaf":[2,3,4],
           "min_samples_split" : [3,5,8,9],
            "max_features":["auto",X.shape[1]/3,2]
            }

# %%
random_model=GridSearchCV(regres,param_grid=parameters1,scoring='neg_mean_squared_error',cv=3,verbose=3)

# %%
random_model.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200;, score=-1844522.887 total time=  16.7s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200;, score=-1871991.778 total time=  18.5s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200;, score=-1913849.328 total time=  17.0s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500;, score=-1830409.760 total time=  43.2s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500;, score=-1866793.130 total time=  41.2s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=500;, score=-1909306.887 total time=  41.7s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=-1850558.514 total time=  16.3s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=-1877437.545 total time=  16.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=-1928808.399 total time=  16.1s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-1840294.901 total time=  41.9s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-1867761.848 total time=  40.1s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=500;, score=-1922786.039 total time=  40.6s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200;, score=-1878133.520 total time=  15.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200;, score=-1899457.451 total time=  15.1s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=200;, score=-1957225.558 total time=  15.4s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-1872604.136 total time=  38.4s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-1890914.557 total time=  38.0s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-1953411.308 total time=  37.5s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=200;, score=-1887935.293 total time=  15.2s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=200;, score=-1908807.745 total time=  15.1s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=200;, score=-1972648.566 total time=  14.9s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=500;, score=-1885230.943 total time=  37.4s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=500;, score=-1898653.412 total time=  37.9s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=9, n_estimators=500;, score=-1968833.208 total time=  37.9s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200;, score=-1891868.238 total time=  15.0s
# [CV 2/3] END max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200;, score=-1913489.518 total time=  15.3s
# [CV 3/3] END max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200;, score=-1979598.765 total time=  15.2s
# [CV 1/3] END max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=500;, score=
total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=8, n_estimators=200;, score=-17052943.479 total time=   0.5s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=8, n_estimators=200;, score=-16649291.970 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=8, n_estimators=200;, score=-17198255.148 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-16807852.478 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-16710577.975 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=8, n_estimators=500;, score=-17392256.782 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=9, n_estimators=200;, score=-16876255.631 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=9, n_estimators=200;, score=-16759336.825 total time=   0.6s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=9, n_estimators=200;, score=-17092518.412 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=9, n_estimators=500;, score=-16770216.213 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=9, n_estimators=500;, score=-16745699.142 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=2, min_samples_split=9, n_estimators=500;, score=-17323838.697 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=200;, score=-16829617.667 total time=   0.5s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=200;, score=-17010475.134 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=200;, score=-17589351.964 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=500;, score=-16937757.550 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=500;, score=-16931529.297 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=500;, score=-17624334.353 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=200;, score=-16829617.667 total time=   0.5s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=200;, score=-17010475.134 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=200;, score=-17589351.964 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=500;, score=-16937757.550 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=500;, score=-16931529.297 total time=   1.4s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=5, n_estimators=500;, score=-17624334.353 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200;, score=-17172920.840 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200;, score=-16817523.126 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200;, score=-17343871.801 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-17181437.525 total time=   1.4s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-16730285.483 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500;, score=-17472942.281 total time=   1.8s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200;, score=-17106603.716 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200;, score=-16976948.970 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200;, score=-17037387.629 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500;, score=-17165277.555 total time=   1.4s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500;, score=-16970244.085 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500;, score=-17438815.767 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=200;, score=-17535629.603 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=200;, score=-17083562.685 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=200;, score=-17528773.736 total time=   0.6s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=500;, score=-17453498.965 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=500;, score=-16947362.194 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=500;, score=-17740020.901 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=-17535629.603 total time=   0.5s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=-17083562.685 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=-17528773.736 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=-17453498.965 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=-16947362.194 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=-17740020.901 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=-17535629.603 total time=   0.5s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=-17083562.685 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=-17528773.736 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500;, score=-17453498.965 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500;, score=-16947362.194 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500;, score=-17740020.901 total time=   1.3s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=200;, score=-17345709.742 total time=   0.6s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=200;, score=-17129133.638 total time=   0.5s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=200;, score=-17344114.869 total time=   0.5s
# [CV 1/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500;, score=-17319180.414 total time=   1.3s
# [CV 2/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500;, score=-17066596.901 total time=   1.3s
# [CV 3/3] END max_depth=7, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500;, score=-17585983.619 total time=   1.3s
# GridSearchCV(cv=3,
#              estimator=RandomForestRegressor(n_estimators=10, random_state=0),
#              param_grid={'max_depth': [None, 4, 5, 6, 7],
#                          'max_features': ['auto', 43.333333333333336, 2],
#                          'min_samples_leaf': [2, 3, 4],
#                          'min_samples_split': [3, 5, 8, 9],
#                          'n_estimators': [200, 500]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
random_model.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 3,
#  'n_estimators': 500}

# %%
random_hyper_model= RandomForestRegressor(n_estimators= 500,max_depth=None,min_samples_leaf=2,min_samples_split=3,max_features='auto')

# %%
random_hyper_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(min_samples_leaf=2, min_samples_split=3, n_estimators=500)

# %%
train_val(random_hyper_model, X_train, y_train, X_test, y_test)
# Out:
#           train        test
# R2        0.989       0.960
# mae     383.357     780.536
# mse  402523.493 1479777.736
# rmse    634.447    1216.461

# %%
y_pred = random_hyper_model.predict(X_test)
ran_R2 = r2_score(y_test, y_pred)
ran_mae = mean_absolute_error(y_test, y_pred)
ran_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# ## Visually Compare Models Performance In a Graph

# %%
scores = {"linear_m": {"r2_score": lm_R2 , 
 "mae": lm_mae, 
 "rmse": lm_rmse},

 "ridge_m": {"r2_score": rm_R2, 
 "mae": rm_mae,
 "rmse": rm_rmse},
    
 "lasso_m": {"r2_score": lasm_R2, 
 "mae": lasm_mae, 
 "rmse": lasm_rmse},

 "elastic_m": {"r2_score": em_R2, 
 "mae": em_mae, 
 "rmse": em_rmse},

 "Decission_m": {"r2_score": des_R2, 
 "mae": des_mae, 
 "rmse": des_rmse},

"Random_m": {"r2_score": ran_R2, 
 "mae": ran_mae, 
 "rmse": ran_rmse},
         
 #"final_m": {"r2_score": fm_R2, 
 #"mae": fm_mae , 
 #"rmse": fm_rmse}
 }
scores = pd.DataFrame(scores).T
scores
# Out:
#              r2_score      mae     rmse
# linear_m        0.898 1419.488 1953.218
# ridge_m         0.898 1419.394 1952.949
# lasso_m         0.898 1418.047 1951.837
# elastic_m       0.898 1418.047 1951.837
# Decission_m     0.937  992.501 1534.664
# Random_m        0.960  780.536 1216.461

# %%
#metrics = scores.columns
for i, j in enumerate(scores):
    plt.figure(i)
    if j == "r2_score":
        ascending = False
    else:
        ascending = True
    compare = scores.sort_values(by=j, ascending=ascending)
    ax = sns.barplot(x = compare[j] , y= compare.index)
    for p in ax.patches:
            width = p.get_width()                        # get bar length
            ax.text(width,                               # set the text at 1 unit right of the bar
                    p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                    '{:.4f}'.format(width),             # set variable to display, 2 decimals
                    ha = 'left',                         # horizontal alignment
                    va = 'center')
